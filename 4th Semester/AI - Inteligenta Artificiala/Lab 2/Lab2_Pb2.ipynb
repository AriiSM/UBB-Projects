# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img1 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Altman.webp')
img2 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\BERT.png')
img3 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\bike.png')
img4 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\chatGPT.png')
img5 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\diffusionModel.jpg')
img6 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Karpaty.jpg')
img7 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\LeCun.jpg')
img8 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Leskovec.jpg')
img9 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Ng.webp')
img10 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Norvig.jpg')
img11 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Russell.jpg')
img12 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Turing.webp')
img13 = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\YOLO.jpg')
fig, axs = plt.subplots(3, 5, figsize=(15, 9))
axs[0, 0].imshow(img1)
axs[0, 1].imshow(img2)
axs[0, 2].imshow(img3)
axs[0, 3].imshow(img4)
axs[0, 4].imshow(img5)
axs[1, 0].imshow(img6)
axs[1, 1].imshow(img7)
axs[1, 2].imshow(img8)
axs[1, 3].imshow(img9)
axs[1, 4].imshow(img10)
axs[2, 0].imshow(img11)
axs[2, 1].imshow(img12)
axs[2, 2].imshow(img13)
#pt a scapa de grile:
# for ax in axs.flat:
#     ax.axis('off')

plt.show()

# %%
#a)sa se vizualizeze una din imagini
img = mpimg.imread('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\BERT.png')
plt.imshow(img)
plt.axis('off')  # Pentru a ascunde axele
plt.show()

# %%
#b)daca imaginile nu au aceeasi dimensiune, sa se redimensioneze toate la 128 x 128 pixeli
#si sa se vizualizeze imaginile intr-un cadru tabelar.
from PIL import Image
img1 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Altman.webp')
img2 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\BERT.png')
img3 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\bike.png')
img4 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\chatGPT.png')
img5 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\diffusionModel.jpg')
img6 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Karpaty.jpg')
img7 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\LeCun.jpg')
img8 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Leskovec.jpg')
img9 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Ng.webp')
img10 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Norvig.jpg')
img11 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Russell.jpg')
img12 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\Turing.webp')
img13 = Image.open('D:\\\\FACULTATE\\\\SEM4\\\\AI\\\\Lab2\\\\imgs\\\\YOLO.jpg')

imagini=[img1,img2,img3,img4,img5,img6,img7,img8,img9,img10,img11,img12,img13]
width, height = imagini[0].size

aceeasi_dimensiune = True
for i in imagini:
    if(i.size != (width, height)):
        aceeasi_dimensiune = False
        break

if not aceeasi_dimensiune:
    imgNou1 = img1.resize((128,128))
    imgNou2 = img2.resize((128,128))
    imgNou3 = img3.resize((128,128))
    imgNou4 = img4.resize((128,128))
    imgNou5 = img5.resize((128,128))
    imgNou6 = img6.resize((128,128))
    imgNou7 = img7.resize((128,128))
    imgNou8 = img8.resize((128,128))
    imgNou9 = img9.resize((128,128))
    imgNou10 = img10.resize((128,128))
    imgNou11 = img11.resize((128,128))
    imgNou12 = img12.resize((128,128))
    imgNou13 = img13.resize((128,128))

    fig, axs = plt.subplots(3, 5, figsize=(15, 9))
    axs[0, 0].imshow(imgNou1)
    axs[0, 1].imshow(imgNou2)
    axs[0, 2].imshow(imgNou3)
    axs[0, 3].imshow(imgNou4)
    axs[0, 4].imshow(imgNou5)
    axs[1, 0].imshow(imgNou6)
    axs[1, 1].imshow(imgNou7)
    axs[1, 2].imshow(imgNou8)
    axs[1, 3].imshow(imgNou9)
    axs[1, 4].imshow(imgNou10)
    axs[2, 0].imshow(imgNou11)
    axs[2, 1].imshow(imgNou12)
    axs[2, 2].imshow(imgNou13)
else:
    print("Imaginile nu au suferit nicio redimensionare")
plt.show()

# %%
#c)sa se transforme imaginile in format gray-levels si sa se vizualizeze
imgGri1 = img1.convert('L')
imgGri2 = img2.convert('L')
imgGri3 = img3.convert('L')
imgGri4 = img4.convert('L')
imgGri5 = img5.convert('L')
imgGri6 = img6.convert('L')
imgGri7 = img7.convert('L')
imgGri8 = img8.convert('L')
imgGri9 = img9.convert('L')
imgGri10 = img10.convert('L')
imgGri11 = img11.convert('L')
imgGri12 = img12.convert('L')
imgGri13 = img13.convert('L')


imgGri1.show()
imgGri2.show()
imgGri3.show()
imgGri4.show()
imgGri5.show()
imgGri6.show()
imgGri7.show()
imgGri8.show()
imgGri9.show()
imgGri10.show()
imgGri11.show()
imgGri12.show()
imgGri13.show()

# %%
#d)sa se blureze o imagine si sa se afiseze in format "before-after"
from PIL import Image, ImageFilter
img_blurred = imgNou1.filter(ImageFilter.BLUR)
fig, axs = plt.subplots(1, 2, figsize=(15, 9))
axs[0].imshow(imgNou1)
axs[1].imshow(img_blurred)
plt.show()

# %%
#e)sa se identifice muchiile dintr-o imagine si sa se afiseze in format "before-after"
muchiile = imgNou8.filter(ImageFilter.FIND_EDGES)

fig, axs = plt.subplots(1, 2, figsize=(15, 9))
axs[0].imshow(imgNou8)
axs[1].imshow(muchiile)
plt.show()
